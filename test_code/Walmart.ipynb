# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import urllib
import json
import sys
import re

def print_r(text):
    print(json.dumps(text, indent=4, sort_keys=False))

api_key = "4tsbjxvbrwnpcjdsh277csqu"
url = "http://api.walmartlabs.com/v1/search" 
params = {
    "apiKey": api_key,
    "format": "json", # json|xml
    "numItems": 25,
    #"start": 1,
    #"categoryId": "3944_3951_1089430_1230093_1230101"
}
params["query"] = "laptop"

# %%
def walmart_search(q):
    params["query"] = q
    walmart_data = requests.get(url, params=params)
    walmart_url = walmart_data.url
    walmart_data = walmart_data.json()
    print(walmart_url)
    #print(walmart_data)
    #result = {}
    #result["totalResults"] = walmart_data["totalResults"]
    #result["start"] = walmart_data["start"]
    #result["numItems"] = walmart_data["numItems"]
    #result["items"] = walmart_data["items"]
    return walmart_data

# %%
params["start"] = 1

query = "Laptop"
re = walmart_search(query)
totalResults =re["totalResults"]
pages = int(round(totalResults/25,0))
print(pages)
out_file = open("walmart_"+query+"_data_file.csv","w")

all_data =[]
out_header = []
out_header.append("itemId")
out_header.append("parentItemId")
#out_header.append("name")
out_header.append("salePrice")
out_header.append("upc")
out_header.append("categoryPath")
out_header.append("numReviews")
out_header.append("customerRating")
#out_header.append("shortDescription")
out_header.append("thumbnailImage")
out_header.append("mediumImage")
out_header.append("largeImage")
out_header.append("categoryNode")
out_header.append("offerType")
# Write the cvs header
out_file.write(','.join(out_header))


ret2=[]

for i in range(1,pages):
    strt = (i*25) - 24;
    if strt<=1000:
        params["start"] = strt
        re = walmart_search(query)
        try:
            if re["numItems"]>0:
                #print_r(re)
                #print(re["items"][0]["name"])
                for x in re["items"]:
                    if "numReviews" not in x:
                        x["numReviews"]=0
                        x["customerRating"]="0.0"
                    if "largeImage" not in x:
                        x["largeImage"]="0.0"
                    if "salePrice" in x and "upc" in x:
                        if "\\" not in x["name"]:
                            out_body = []
                            item_data = {}
                            item_data["itemId"] = x["itemId"]
                            out_body.append(str(x["itemId"]))
                            item_data["parentItemId"] = x["parentItemId"]
                            out_body.append(str(x["parentItemId"]))
                            try:
                            #    out_body.append(str(x["name"]))
                                item_data["name"] = x["name"]
                            except (KeyError, IndexError):
                            #    out_body.append(str("Error with the name"))
                                item_data["name"] = "Error with the name"

                            #out_body.append(x["name"].encode('utf-8'))
                            #out_body.append(str(x["name"]))
                            out_body.append(str(x["salePrice"]))
                            item_data["salePrice"] = x["salePrice"]
                            out_body.append(x["upc"])
                            item_data["upc"] = x["upc"]
                            out_body.append(x["categoryPath"])
                            item_data["categoryPath"] = x["categoryPath"]
                            out_body.append(str(x["numReviews"]))
                            item_data["numReviews"] = x["numReviews"]
                            out_body.append(x["customerRating"])
                            item_data["customerRating"] = x["customerRating"]
                            #out_body.append(x["shortDescription"])
                            out_body.append(x["thumbnailImage"])
                            item_data["thumbnailImage"] = x["thumbnailImage"]
                            out_body.append(x["mediumImage"])
                            item_data["mediumImage"] = x["mediumImage"]
                            out_body.append(x["largeImage"])
                            item_data["largeImage"] = x["largeImage"]
                            out_body.append(x["categoryNode"])
                            item_data["categoryNode"] = x["categoryNode"]
                            #item_data["screensize"] = re.findall(r'[0-9\.]+"', item_data["name"])[0].replace("\"","")
                            out_body.append(x["offerType"])
                            # Write the cvs header
                            #out_file.write(','.join(out_body))
                            #print_r(out_body)
                            out_file.write("\n"+','.join(out_body))
                            all_data.append(item_data)
        
        except (KeyError, IndexError):
            print("Missing field/result... skipping.")
    #print(row["upc"], index)
out_file.close() # Close the new datafile
print("We Finished, but not yet")
results_pd = pd.DataFrame(all_data)

results_pd.head()
# Out:
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=1
# 852
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=1
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=26
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=51
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=76
# Missing field/result... skipping.
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=101
# Missing field/result... skipping.
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=126
# Missing field/result... skipping.
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=151
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=176
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=201
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=226
# Missing field/result... skipping.
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=251
# Missing field/result... skipping.
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=276
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=301
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=326
# Missing field/result... skipping.
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=351
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=376
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=401
# Missing field/result... skipping.
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=426
# Missing field/result... skipping.
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=451
# Missing field/result... skipping.
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=476
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=501
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=526
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=551
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=576
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=601
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=626
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=651
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=676
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=701
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=726
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=751
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=776
# Missing field/result... skipping.
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=801
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=826
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=851
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=876
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=901
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=926
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=951
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&numItems=25&query=Laptop&start=976
# We Finished, but not yet
#         categoryNode                                       categoryPath  \
# 0  3944_3951_1089430  Electronics/Computers/Laptops/Shop Laptops by ...
# 1  3944_3951_1089430  Electronics/Computers/Laptops/Shop Laptops by ...
# 2  3944_3951_1089430  Electronics/Computers/Laptops/Shop Laptops by ...
# 3  3944_3951_1089430  Electronics/Computers/Laptops/Shop Laptops by ...
# 4  3944_3951_1089430  Electronics/Computers/Laptops/Shop Laptops by ...
#
#   customerRating     itemId  \
# 0          4.667  322570741
# 1          4.467  822597407
# 2          3.857   55499365
# 3          4.714  700792078
# 4          4.348   55009828
#
#                                           largeImage  \
# 0  https://i5.walmartimages.com/asr/a5ec9c67-9a09...
# 1  https://i5.walmartimages.com/asr/c9095299-7506...
# 2  https://i5.walmartimages.com/asr/45426f9d-8ac4...
# 3  https://i5.walmartimages.com/asr/730c7807-89f9...
# 4  https://i5.walmartimages.com/asr/c0ab938b-41f5...
#
#                                          mediumImage  \
# 0  https://i5.walmartimages.com/asr/a5ec9c67-9a09...
# 1  https://i5.walmartimages.com/asr/c9095299-7506...
# 2  https://i5.walmartimages.com/asr/45426f9d-8ac4...
# 3  https://i5.walmartimages.com/asr/730c7807-89f9...
# 4  https://i5.walmartimages.com/asr/c0ab938b-41f5...
#
#                                                 name  numReviews  \
# 0  HP Pavilion 15-cs0051wm 15.6 Touchscreen Lapto...           3
# 1  HP Pavilion 15-br082wm X360 15.6" Touchscreen ...          31
# 2  SAMSUNG Chromebook Plus 12.3"Chrome OS 32GB eM...          56
# 3  HP 15-da053wm 15.6" Touch Laptop, Windows 10 H...          14
# 4  Acer 15.6" Chromebook CB5-571-C4G4, Intel Cele...          21
#
#    parentItemId  salePrice                                     thumbnailImage  \
# 0     322570741     639.00  https://i5.walmartimages.com/asr/a5ec9c67-9a09...
# 1     822597407     499.00  https://i5.walmartimages.com/asr/c9095299-7506...
# 2      55499365     429.95  https://i5.walmartimages.com/asr/45426f9d-8ac4...
# 3     700792078     559.00  https://i5.walmartimages.com/asr/730c7807-89f9...
# 4      55009828     179.00  https://i5.walmartimages.com/asr/c0ab938b-41f5...
#
#             upc
# 0  192545383455
# 1  192018968349
# 2  887276183961
# 3  192545383752
# 4  888863275496

# %%
out_file = "walmart_"+query+"_data_file2.csv"
print(out_file)
results_pd.to_csv(out_file, sep=',')
# Out:
# walmart_Laptop_data_file2.csv

# %%
results_pd = pd.DataFrame(all_data)
results_pd = results_pd[["itemId",
                         "upc",
                         "name",
                         "salePrice",
                         "parentItemId",
                         "categoryNode",
                         "categoryPath",
                         "largeImage",
                         "mediumImage",
                         "customerRating",
                         "numReviews",
                         "thumbnailImage"]]
results_pd.head()
results_pd
