# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import urllib
import json
import sys
import re

def print_r(text):
    print(json.dumps(text, indent=4, sort_keys=False))

api_key = "4tsbjxvbrwnpcjdsh277csqu"
url = "http://api.walmartlabs.com/v1/search" 
params = {
    "apiKey": api_key,
    "format": "json", # json|xml
    "numItems": 25,
    #"start": 1,
    #"categoryId": "3944_3951_1089430_1230093_1230101"
}
params["query"] = "laptop"

# %%
def walmart_search(q):
    params["query"] = q
    walmart_data = requests.get(url, params=params)
    walmart_url = walmart_data.url
    walmart_data = walmart_data.json()
    #print(walmart_url)
    #print(walmart_data)
    #result = {}
    #result["totalResults"] = walmart_data["totalResults"]
    #result["start"] = walmart_data["start"]
    #result["numItems"] = walmart_data["numItems"]
    #result["items"] = walmart_data["items"]
    return walmart_data

# %%
params["start"] = 1
query = "TV"
query = "Laptop"
query = "887276189529"
re = walmart_search(query)
if re["numItems"]>0:
    print_r(re)

# %%
types_df = pd.read_csv("BestBuy_Data.csv")
types_df.head()
# Out:
#             upc  customerReviewAverage  customerReviewCount  \
# 0  884116293927                    NaN                  NaN
# 1  884116293392                    NaN                  NaN
# 2  719192618893                    NaN                  NaN
# 3  719192618930                    NaN                  NaN
# 4  719192619395                    NaN                  NaN
#
#    inStoreAvailability manufacturer  \
# 0                 True         Dell
# 1                 True         Dell
# 2                 True           LG
# 3                 True           LG
# 4                 True           LG
#
#                                                 name  onlineAvailability  \
# 0  Dell - 17.3" Laptop - Intel Core i7 - 16GB Mem...                True
# 1  Dell - Inspiron 15.6" Laptop - AMD Ryzen 3 - 4...                True
# 2  LG - gram 13.3" Laptop - Intel Core i5 - 8GB M...                True
# 3  LG - gram 14" Touch-Screen Laptop - Intel Core...                True
# 4  LG - gram 15.6" Touch-Screen Laptop - Intel Co...                True
#
#    regularPrice  salePrice
# 0       1099.99    1099.99
# 1        499.99     499.99
# 2       1099.99    1099.99
# 3       1549.99    1549.99
# 4       1999.99    1999.99

# %%
import re
out_file = open("walmart_All_data_file2.csv","w")
all_data =[]
out_header = []
out_header.append("itemId")
out_header.append("parentItemId")
#out_header.append("name")
out_header.append("salePrice")
out_header.append("upc")
out_header.append("categoryPath")
out_header.append("numReviews")
out_header.append("customerRating")
#out_header.append("shortDescription")
out_header.append("thumbnailImage")
out_header.append("mediumImage")
out_header.append("largeImage")
out_header.append("categoryNode")
#out_header.append("offerType")
# Write the cvs header
out_file.write(','.join(out_header))

for index, row in types_df.iterrows():
    query = row["upc"]
    re = walmart_search(query)
    try:
        if re["numItems"]>0:
            #print_r(re)
            #print(re["items"][0]["name"])
            for x in re["items"]:
                if "numReviews" not in x:
                    x["numReviews"]=0
                    x["customerRating"]="0.0"
                if "largeImage" not in x:
                    x["largeImage"]="0.0"
                if "salePrice" in x and "upc" in x:
                    if "\\" not in x["name"]:
                        out_body = []
                        item_data = {}
                        item_data["itemId"] = x["itemId"]
                        out_body.append(str(x["itemId"]))
                        item_data["parentItemId"] = x["parentItemId"]
                        out_body.append(str(x["parentItemId"]))
                        #x["name"] = x["name"].encode('UTF-8')
                        try:
                            out_body.append(str(x["name"]))
                            item_data["name"] = x["name"]
                        except (KeyError, IndexError):
                            out_body.append(str("Error with the name"))
                            item_data["name"] = "Error with the name"
                        item_data["screensize"] = 0
                        #out_body.append(x["name"].encode('utf-8'))
                        #out_body.append(str(x["name"]))
                        out_body.append(str(x["salePrice"]))
                        item_data["salePrice"] = x["salePrice"]
                        out_body.append(x["upc"])
                        item_data["upc"] = x["upc"]
                        out_body.append(x["categoryPath"])
                        item_data["categoryPath"] = x["categoryPath"]
                        out_body.append(str(x["numReviews"]))
                        item_data["numReviews"] = x["numReviews"]
                        out_body.append(x["customerRating"])
                        item_data["customerRating"] = x["customerRating"]
                        #out_body.append(x["shortDescription"])
                        out_body.append(x["thumbnailImage"])
                        item_data["thumbnailImage"] = x["thumbnailImage"]
                        out_body.append(x["mediumImage"])
                        item_data["mediumImage"] = x["mediumImage"]
                        out_body.append(x["largeImage"])
                        item_data["largeImage"] = x["largeImage"]
                        out_body.append(x["categoryNode"])
                        item_data["categoryNode"] = x["categoryNode"]
                        #out_body.append(x["offerType"])
                        # Write the cvs header
                        #out_file.write(','.join(out_body))
                        #print_r(out_body)
                        out_file.write("\n"+','.join(out_body))
                        all_data.append(item_data)
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
    #print(row["upc"], index)
out_file.close() # Close the new datafile
print("We Finished, but not yet")
results_pd = pd.DataFrame(all_data)
results_pd.head()
# Out:
# Dell - G3 17.3" Gaming Laptop, Intel Core i7-8750H, NVIDIA 1050Ti 4GB GPU, 16GB RAM, 128GB SSD + 1TB Storage, G3779-7927BLK-PUS, Gaming Bundle Included
# LG gram 13.3" Intel 8th Gen i5-8250U Ultra-Slim Laptop - 13Z980-U.AAW5U1
# LG gram 14.0" Intel 8th Gen i7-8550U Ultra-Slim Touch Laptop - 14Z980-A.AAS7U1
# LG 15Z980RAAS9 15Z980-R.AAS9U1 gram 15.6" i7, 16GB, 1TB SSD, Windows 10 Touchscreen Laptop
# Acer Spin 1 11.6" Laptop Intel Celeron 2.4 GHz 4GB Ram 32GB Flash Windows 10 | Manufacturer Refurbished
# Missing field/result... skipping.
# Missing field/result... skipping.
# Acer 15.6" Intel Celeron 1.5GHz 4GB Ram 16GB SSD Chrome OS| FR/ENG Edition | Manufacturer Refurbished
# Manufacturer Refurbished Acer CB3-532-C47C 15.6" Chromebook, Chrome OS, Intel Celeron N3060 Processor, 2GB RAM, 16GB Flash Drive
# Acer 17.3" Intel Core i7 2.90 GHz 64 GB Ram Windows 10 Home | GX-792-75MV | Manufacturer Refurbished
# Refurbished Acer Predator Laptop Intel Core i7 2.8 GHz 32 GB Ram 512 GB SSD Windows 10 Home
# Refurbished Acer 15.6" Nitro Notebook Intel Core i7 2.8GHz 16GB 512GB SSD Win10Home
# Acer Laptop Intel Celeron 1.60 GHz 4GB Ram 32GB SSD Chrome OS | FR/ENG Edition | Manufacturer Refurbished
# Asus Zenbook 13 UX331UA-DS71 13.3" LCD Notebook - Intel Core i7 (8th Gen) i7-8550U Quad-core (4 Core) 1.8GHz - 8GB LPDDR3 - 256GB SSD - Windows 10
# Asus VivoBook Pro 15 15.6" Gaming Laptop i7-8750H 8GB 16GB 1TB GTX 1050
# ASUS ZenBook S UX391UA-XB74T Ultra-thin and light 13.3-inch UHD 4K Touch Laptop, Intel Core i7-8550U, 16GB 2133MHz RAM ,512GB PCIE G3X4 SSD, Windows 10 Pro, FP Sensor, Thunderbolt
# Asus VivoBook 15 F542UA-DB71 15.6" Notebook - Intel Core i7-7500U 2.7GHz (Turbo up to 4GHz) - 8GB DDR4 - 256GB SSD - Windows 10
# STAR GREYNO TOUCH SCREEN17.3 HD+ (1600,9
# Asus 217052 Nb Gm501gm-ws74 15.6 Rog I7-8750h 16gb 256gb+1tb W10 Geforce Gtx1060 Rtl
# 15.6" i7-8750H 16GB 256GB Win1 (90NR00L1-M02140) (192876068687) (ASUS Notebooks)
# Asus 15.6" i7-8750H 16GB 256GB Win1
# HP ZBook 14u G4 Mobile Workstation - 14" - Core i5 7200U - 4 GB RAM - 500 GB HDD - US
# Asus 15.6" i5-8250U 4GB 1TB Win10
# Asus 15.6" E2-6110 4GB 500GB Win10
# ASUS X540UA-DB71 Laptop Computer, Intel Core i7-8550U Processor, 8GB RAM, 1TB SSHD, 15.6” FHD Display, Windows 10
# Missing field/result... skipping.
# Missing field/result... skipping.
# ASUS 10.1" Quad Core 4GB 128GB
# Asus VivoBook 15 X540UA-DB51 15.6" Laptop i5-8250U 8GB 1TB HHD Windows 10
# VIZIO 75" Class P-Series 4K (2160P) Ultra HD HDR Smart LED TV (P75-F1) (2018 Model)
# LG 55" OLED 4K HDR Smart OLED TV w/AI ThinQ 55OLEDE8PUA
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# LG 75" Class 4K (2160) HDR Smart Super UHD TV w/AI ThinQ - 75SK8070PUA
# VIZIO 55" Class E-Series 4K (2160P) Ultra HD HDR Smart LED TV (E55-F1) (2018 Model)
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# LG 65" Class 4K (2160) HDR Smart LED UHD TV w/AI ThinQ - 65UK6300PUE
# VIZIO 55" Class M-Series 4K (2160P) Ultra HD HDR Smart LED TV (M55-F0) (2018 Model)
# VIZIO 50" Class 4K (2160P) Smart LED Home Theater Display (E50-E1)
# SAMSUNG 50'' Class FHD (1080P) Smart LED TV (UN50M5300)
# SAMSUNG 43" Class Frame 4K (2160P) Ultra HD Smart LED TV (UN43LS003)
# SAMSUNG 65" Class 4K (2160P) Ultra HD Smart QLED HDR TV QN65Q9FN (2018 model)
# VIZIO 48" Class FHD (1080P) Smart LED TV (D48f-E0)
# VIZIO 70" Class 4K (2160P) Smart XLED Home Theater Display (E70-E3)
# SAMSUNG 65" Class Curved 4K (2160P) Ultra HD Smart QLED HDR TV (QN65Q8CAMFXZA)
# LG 55SJ8500 55" Super UHD 4K HDR Smart LED TV
# Missing field/result... skipping.
# Missing field/result... skipping.
# TCL 43" Class 4K (2160P) Roku Smart LED TV (43S405)
# VIZIO 24" Class SmartCast D-Series FHD (1080P) Smart LED TV (D24f-F1) (2018 Model)
# Hisense 65" Class 4K(2160p) Smart LED TV (65H9PLUS)
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# LG 65" Class 4K (2160) HDR Smart Super UHD TV w/AI ThinQ - 65SK9000PUA
# LG 65" OLED 4K HDR Smart OLED TV w/AI ThinQ - OLED65C8PUA
# SAMSUNG 75" Class 4K (2160P) Ultra HD Smart LED TV UN75NU8000FXZA (2018 model)
# LG 70" Class 4K (2160) HDR Smart LED UHD TV w/AI ThinQ - 70UK6570PUB
# LG 65" OLED 4K HDR Smart OLED TV w/AI ThinQ - OLED65E8PUA
# SAMSUNG 65" Class 4K (2160P) Ultra HD Smart LED TV UN65NU8000FXZA (2018 model)
# SAMSUNG 75" Class 4K(2160P) Ultra HD Smart QLED HDR TV QN75Q6FN (2018 model)
# LG 55" Class 4K (2160) HDR Smart Super UHD TV w/AI ThinQ - 55SK9000PUA
# SAMSUNG 55" Class Curved 4K (2160P) Ultra HD Smart LED TV UN55NU8500FXZA (2018 model)
# SAMSUNG 88" Class 4K (2160P) Ultra HD Smart QLED HDR TV (QN88Q9F)
# TCL 40" Class FHD (1080P) Roku Smart LED TV (40S305)
# SAMSUNG 65" Class Curved 4K (2160P) Ultra HD Smart QLED HDR TV QN65Q7CN (2018 model)
# Samsung 55" Class 4K (2160P) Curved Smart QLED TV QN55Q7CN (2018 Model)
# Missing field/result... skipping.
# Missing field/result... skipping.
# VIZIO 65" Class M-Series 4K (2160P) Ultra HD HDR Smart LED TV (M65-F0) (2018 Model)
# SAMSUNG 49" Class 4K (2160P) Ultra HD Smart QLED HDR TV QN49Q6FN (2018 Model)
# LG 55" OLED 4K HDR Smart OLED TV w/AI ThinQ - OLED55B8PUA
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Samsung UN55LS03N 55" Frame 4K UHD HDR Smart TV with Bixby Intelligent Voice Assistant
# Samsung UN65LS03N 65" Frame 4K UHD HDR Smart TV with Bixby Intelligent Voice Assistant
# Missing field/result... skipping.
# We Finished, but not yet
#         categoryNode                                       categoryPath  \
# 0  3944_3951_1089430  Electronics/Computers/Laptops/Shop Laptops by ...
# 1  3944_3951_1089430  Electronics/Computers/Laptops/Shop Laptops by ...
# 2  3944_3951_1089430  Electronics/Computers/Laptops/Shop Laptops by ...
# 3  3944_3951_1089430  Electronics/Computers/Laptops/Shop Laptops by ...
# 4  3944_3951_1089430  Electronics/Computers/Laptops/Shop Laptops by ...
#
#   customerRating     itemId  \
# 0            0.0  260594775
# 1            0.0  486905649
# 2            4.2  788821428
# 3          4.539  654858649
# 4            0.0  862797804
#
#                                           largeImage  \
# 0  https://i5.walmartimages.com/asr/96cb0f94-ba75...
# 1  https://i5.walmartimages.com/asr/35c9950e-302a...
# 2  https://i5.walmartimages.com/asr/7cb981b5-e0f8...
# 3  https://i5.walmartimages.com/asr/3ebc392e-c378...
# 4  https://i5.walmartimages.com/asr/03fc34d6-2e08...
#
#                                          mediumImage  \
# 0  https://i5.walmartimages.com/asr/96cb0f94-ba75...
# 1  https://i5.walmartimages.com/asr/35c9950e-302a...
# 2  https://i5.walmartimages.com/asr/7cb981b5-e0f8...
# 3  https://i5.walmartimages.com/asr/3ebc392e-c378...
# 4  https://i5.walmartimages.com/asr/03fc34d6-2e08...
#
#                                                 name  numReviews  \
# 0  Dell - G3 17.3" Gaming Laptop, Intel Core i7-8...           0
# 1  LG gram 13.3" Intel 8th Gen i5-8250U Ultra-Sli...           0
# 2  LG gram 14.0" Intel 8th Gen i7-8550U Ultra-Sli...           5
# 3  LG 15Z980RAAS9 15Z980-R.AAS9U1 gram 15.6" i7, ...          13
# 4  Acer Spin 1 11.6" Laptop Intel Celeron 2.4 GHz...           0
#
#    parentItemId  salePrice  screensize  \
# 0     260594775    1104.00           0
# 1     486905649     996.99           0
# 2     788821428    1396.99           0
# 3     654858649    1839.00           0
# 4     862797804     278.44           0
#
#                                       thumbnailImage           upc
# 0  https://i5.walmartimages.com/asr/96cb0f94-ba75...  884116293927
# 1  https://i5.walmartimages.com/asr/35c9950e-302a...  719192618893
# 2  https://i5.walmartimages.com/asr/7cb981b5-e0f8...  719192618930
# 3  https://i5.walmartimages.com/asr/3ebc392e-c378...  719192619395
# 4  https://i5.walmartimages.com/asr/03fc34d6-2e08...  841631121746

# %%
import re
results_pd = pd.DataFrame(all_data)
results_pd = results_pd[["itemId",
                         "upc",
                         "name",
                         "salePrice",
                         "parentItemId",
                         "categoryNode",
                         "categoryPath",
                         "largeImage",
                         "screensize",
                         "mediumImage",
                         "customerRating",
                         "numReviews",
                         "thumbnailImage"]]
#results_pd.head()
results_pd
all_data = []
for index, row in results_pd.iterrows():
    try:
        screensize = re.findall(r'[0-9\.]+"', row["name"])[0].replace("\"","")
        
        #memory = re.findall(r'[0-9]+GB Memory', row["name"])[0].replace("GB Memory","")
        memory = re.findall(r'[0-9]+GB [Rr][Aa][Mm]', row["name"])
        memorylen = len(memory)
        if memorylen==0:
            memory = re.findall(r'[0-9]+GB', row["name"])
            if(memorylen>2):
                memory = memory[1]
            else:
                memory = memory[0]
        else:
            memory = memory[0]
        memory = memory.replace("GB Ram","").replace("GB RAM","").replace("GB","")
        print(memory)
        #memory = re.findall(r'[0-9]+GB Memory', row["name"])[0]
    except (KeyError, IndexError):
        screensize = 0
        proccessor = 0
        memory = 0
    #print(screensize, memory)
    results_pd["screensize"] = screensize
    all_data.append(row)
    #print(row["name"])

results_pd = pd.DataFrame(all_data)
results_pd
results_pdout_file

# %%
df2 = results_pd[(results_pd.categoryNode=='3944_1060825_9465212') | (results_pd.categoryNode=='3944_3951_1089430')]
df2.head()

# %%
import re
#Dell - 17.3" Laptop - Intel Core i7 - 16GB Memory - NVIDIA GeForce GTX 1050 Ti - 1TB Hard Drive + 128GB Solid State Drive - Black
for index, row in types_df.iterrows():
    try:
        screensize = re.findall(r'[0-9\.]+"', row["name"])[0].replace("\"","")
        memory = re.findall(r'[0-9]+GB Memory', row["name"])[0]
    except (KeyError, IndexError):
        screensize = 0
        proccessor = 0
        memory = 0
    print(memory)
