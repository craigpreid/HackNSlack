# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import urllib
import json
import sys
import re

def print_r(text):
    print(json.dumps(text, indent=4, sort_keys=False))

api_key = "4tsbjxvbrwnpcjdsh277csqu"
url = "http://api.walmartlabs.com/v1/search" 
params = {
    "apiKey": api_key,
    "format": "json", # json|xml
    "numItems": 25,
    #"start": 1,
    #"categoryId": "3944_3951_1089430_1230093_1230101"
}
params["query"] = "laptop"

# %%
def walmart_search(q):
    params["query"] = q
    walmart_data = requests.get(url, params=params)
    walmart_url = walmart_data.url
    walmart_data = walmart_data.json()
    #print(walmart_url)
    #print(walmart_data)
    #result = {}
    #result["totalResults"] = walmart_data["totalResults"]
    #result["start"] = walmart_data["start"]
    #result["numItems"] = walmart_data["numItems"]
    #result["items"] = walmart_data["items"]
    return walmart_data

# %%
params["start"] = 1
query = "TV"
query = "Laptop"
query = "887276189529"
re = walmart_search(query)
if re["numItems"]>0:
    print_r(re)

# %%
types_df = pd.read_csv("BestBuy_Data.csv")
types_df.head()
# Out:
#             upc  customerReviewAverage  customerReviewCount  \
# 0  884116293927                    NaN                  NaN
# 1  884116293392                    NaN                  NaN
# 2  719192618893                    NaN                  NaN
# 3  719192618930                    NaN                  NaN
# 4  719192619395                    NaN                  NaN
#
#    inStoreAvailability manufacturer  \
# 0                 True         Dell
# 1                 True         Dell
# 2                 True           LG
# 3                 True           LG
# 4                 True           LG
#
#                                                 name  onlineAvailability  \
# 0  Dell - 17.3" Laptop - Intel Core i7 - 16GB Mem...                True
# 1  Dell - Inspiron 15.6" Laptop - AMD Ryzen 3 - 4...                True
# 2  LG - gram 13.3" Laptop - Intel Core i5 - 8GB M...                True
# 3  LG - gram 14" Touch-Screen Laptop - Intel Core...                True
# 4  LG - gram 15.6" Touch-Screen Laptop - Intel Co...                True
#
#    regularPrice  salePrice
# 0       1099.99    1099.99
# 1        499.99     499.99
# 2       1099.99    1099.99
# 3       1549.99    1549.99
# 4       1999.99    1999.99

# %%
import re
out_file = open("walmart_All_data_file2.csv","w")
all_data =[]
out_header = []
out_header.append("itemId")
out_header.append("parentItemId")
#out_header.append("name")
out_header.append("salePrice")
out_header.append("upc")
out_header.append("categoryPath")
out_header.append("numReviews")
out_header.append("customerRating")
#out_header.append("shortDescription")
out_header.append("thumbnailImage")
out_header.append("mediumImage")
out_header.append("largeImage")
out_header.append("categoryNode")
#out_header.append("offerType")
# Write the cvs header
out_file.write(','.join(out_header))

for index, row in types_df.iterrows():
    query = row["upc"]
    re = walmart_search(query)
    try:
        if re["numItems"]>0:
            #print_r(re)
            #print(re["items"][0]["name"])
            for x in re["items"]:
                if "numReviews" not in x:
                    x["numReviews"]=0
                    x["customerRating"]="0.0"
                if "largeImage" not in x:
                    x["largeImage"]="0.0"
                if "salePrice" in x and "upc" in x:
                    if "\\" not in x["name"]:
                        out_body = []
                        item_data = {}
                        item_data["itemId"] = x["itemId"]
                        out_body.append(str(x["itemId"]))
                        item_data["parentItemId"] = x["parentItemId"]
                        out_body.append(str(x["parentItemId"]))
                        #x["name"] = x["name"].encode('UTF-8')
                        try:
                            out_body.append(str(x["name"]))
                            item_data["name"] = x["name"]
                        except (KeyError, IndexError):
                            out_body.append(str("Error with the name"))
                            item_data["name"] = "Error with the name"
                        item_data["screensize"] = 0
                        #out_body.append(x["name"].encode('utf-8'))
                        #out_body.append(str(x["name"]))
                        out_body.append(str(x["salePrice"]))
                        item_data["salePrice"] = x["salePrice"]
                        out_body.append(x["upc"])
                        item_data["upc"] = x["upc"]
                        out_body.append(x["categoryPath"])
                        item_data["categoryPath"] = x["categoryPath"]
                        out_body.append(str(x["numReviews"]))
                        item_data["numReviews"] = x["numReviews"]
                        out_body.append(x["customerRating"])
                        item_data["customerRating"] = x["customerRating"]
                        #out_body.append(x["shortDescription"])
                        out_body.append(x["thumbnailImage"])
                        item_data["thumbnailImage"] = x["thumbnailImage"]
                        out_body.append(x["mediumImage"])
                        item_data["mediumImage"] = x["mediumImage"]
                        out_body.append(x["largeImage"])
                        item_data["largeImage"] = x["largeImage"]
                        out_body.append(x["categoryNode"])
                        item_data["categoryNode"] = x["categoryNode"]
                        out_body.append(x["offerType"])
                        item_data["offerType"] = x["offerType"]
                        # Write the cvs header
                        #out_file.write(','.join(out_body))
                        #print_r(out_body)
                        out_file.write("\n"+','.join(out_body))
                        all_data.append(item_data)
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
    #print(row["upc"], index)
out_file.close() # Close the new datafile
print("We Finished, but not yet")
results_pd = pd.DataFrame(all_data)
results_pd.head()
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# We Finished, but not yet
#         categoryNode                                       categoryPath  \
# 0  3944_3951_1089430  Electronics/Computers/Laptops/Shop Laptops by ...
# 1  3944_3951_1089430  Electronics/Computers/Laptops/Shop Laptops by ...
# 2  3944_3951_1089430  Electronics/Computers/Laptops/Shop Laptops by ...
# 3  3944_3951_1089430  Electronics/Computers/Laptops/Shop Laptops by ...
# 4  3944_3951_1089430  Electronics/Computers/Laptops/Shop Laptops by ...
#
#   customerRating     itemId  \
# 0            0.0  260594775
# 1            0.0  486905649
# 2            4.2  788821428
# 3          4.539  654858649
# 4            0.0  862797804
#
#                                           largeImage  \
# 0  https://i5.walmartimages.com/asr/96cb0f94-ba75...
# 1  https://i5.walmartimages.com/asr/35c9950e-302a...
# 2  https://i5.walmartimages.com/asr/7cb981b5-e0f8...
# 3  https://i5.walmartimages.com/asr/3ebc392e-c378...
# 4  https://i5.walmartimages.com/asr/03fc34d6-2e08...
#
#                                          mediumImage  \
# 0  https://i5.walmartimages.com/asr/96cb0f94-ba75...
# 1  https://i5.walmartimages.com/asr/35c9950e-302a...
# 2  https://i5.walmartimages.com/asr/7cb981b5-e0f8...
# 3  https://i5.walmartimages.com/asr/3ebc392e-c378...
# 4  https://i5.walmartimages.com/asr/03fc34d6-2e08...
#
#                                                 name  numReviews    offerType  \
# 0  Dell - G3 17.3" Gaming Laptop, Intel Core i7-8...           0  ONLINE_ONLY
# 1  LG gram 13.3" Intel 8th Gen i5-8250U Ultra-Sli...           0  ONLINE_ONLY
# 2  LG gram 14.0" Intel 8th Gen i7-8550U Ultra-Sli...           5  ONLINE_ONLY
# 3  LG 15Z980RAAS9 15Z980-R.AAS9U1 gram 15.6" i7, ...          13  ONLINE_ONLY
# 4  Acer Spin 1 11.6" Laptop Intel Celeron 2.4 GHz...           0  ONLINE_ONLY
#
#    parentItemId  salePrice  screensize  \
# 0     260594775    1104.00           0
# 1     486905649     996.99           0
# 2     788821428    1396.99           0
# 3     654858649    1839.00           0
# 4     862797804     278.44           0
#
#                                       thumbnailImage           upc
# 0  https://i5.walmartimages.com/asr/96cb0f94-ba75...  884116293927
# 1  https://i5.walmartimages.com/asr/35c9950e-302a...  719192618893
# 2  https://i5.walmartimages.com/asr/7cb981b5-e0f8...  719192618930
# 3  https://i5.walmartimages.com/asr/3ebc392e-c378...  719192619395
# 4  https://i5.walmartimages.com/asr/03fc34d6-2e08...  841631121746

# %%
import re
results_pd = pd.DataFrame(all_data)
results_pd = results_pd[["itemId",
                         "upc",
                         "name",
                         "salePrice",
                         "parentItemId",
                         "categoryNode",
                         "categoryPath",
                         "largeImage",
                         "screensize",
                         "mediumImage",
                         "customerRating",
                         "numReviews",
                         "thumbnailImage",
                         "offerType"]]
#results_pd.head()
results_pd
all_data = []
for index, row in results_pd.iterrows():
    try:
        screensize = re.findall(r'[0-9\.]+"', row["name"])[0].replace("\"","")
        
        #memory = re.findall(r'[0-9]+GB Memory', row["name"])[0].replace("GB Memory","")
        memory = re.findall(r'[0-9]+GB [Rr][Aa][Mm]', row["name"])
        memorylen = len(memory)
        if memorylen==0:
            memory = re.findall(r'[0-9]+GB', row["name"])
            if(memorylen>2):
                memory = memory[1]
            else:
                memory = memory[0]
        else:
            memory = memory[0]
        memory = memory.replace("GB Ram","").replace("GB RAM","").replace("GB","")
        print(memory)
        #memory = re.findall(r'[0-9]+GB Memory', row["name"])[0]
    except (KeyError, IndexError):
        screensize = 0
        proccessor = 0
        memory = 0
    #print(screensize, memory)
    results_pd["screensize"] = screensize
    all_data.append(row)
    #print(row["name"])

results_pd = pd.DataFrame(all_data)
results_pd.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-8090a4c22f04> in <module>()
#      14                          "numReviews",
#      15                          "thumbnailImage",
# ---> 16                          "offerType"]]
#      17 #results_pd.head()
#      18 results_pd
#
# C:\ProgramData\Anaconda31\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# C:\ProgramData\Anaconda31\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
#
# C:\ProgramData\Anaconda31\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['offerType'] not in index"

# %%
import re
results_pd = pd.DataFrame(all_data)
results_pd = results_pd[["itemId",
                         "upc",
                         "name",
                         "salePrice",
                         "parentItemId",
                         "categoryNode",
                         "categoryPath",
                         "largeImage",
                         "screensize",
                         "mediumImage",
                         "customerRating",
                         "numReviews",
                         "thumbnailImage"]]
#results_pd.head()
results_pd
all_data = []
for index, row in results_pd.iterrows():
    try:
        screensize = re.findall(r'[0-9\.]+"', row["name"])[0].replace("\"","")
        
        #memory = re.findall(r'[0-9]+GB Memory', row["name"])[0].replace("GB Memory","")
        memory = re.findall(r'[0-9]+GB [Rr][Aa][Mm]', row["name"])
        memorylen = len(memory)
        if memorylen==0:
            memory = re.findall(r'[0-9]+GB', row["name"])
            if(memorylen>2):
                memory = memory[1]
            else:
                memory = memory[0]
        else:
            memory = memory[0]
        memory = memory.replace("GB Ram","").replace("GB RAM","").replace("GB","")
        print(memory)
        #memory = re.findall(r'[0-9]+GB Memory', row["name"])[0]
    except (KeyError, IndexError):
        screensize = 0
        proccessor = 0
        memory = 0
    #print(screensize, memory)
    results_pd["screensize"] = screensize
    all_data.append(row)
    #print(row["name"])

results_pd = pd.DataFrame(all_data)
results_pd
results_pdout_file

# %%
df2 = results_pd[(results_pd.categoryNode=='3944_1060825_9465212') | (results_pd.categoryNode=='3944_3951_1089430')]
df2.head()

# %%
import re
#Dell - 17.3" Laptop - Intel Core i7 - 16GB Memory - NVIDIA GeForce GTX 1050 Ti - 1TB Hard Drive + 128GB Solid State Drive - Black
for index, row in types_df.iterrows():
    try:
        screensize = re.findall(r'[0-9\.]+"', row["name"])[0].replace("\"","")
        memory = re.findall(r'[0-9]+GB Memory', row["name"])[0]
    except (KeyError, IndexError):
        screensize = 0
        proccessor = 0
        memory = 0
    print(memory)
