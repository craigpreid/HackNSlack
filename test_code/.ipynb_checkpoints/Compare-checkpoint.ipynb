# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import urllib
import json
import sys
import re

# %%
# # open and clean walmart data file
# filepath = os.path.join('Walmart_datasets/walmart_Laptop_data_file.csv')
# with open(filepath, 'r') as csvfile:
#     csvreader = csv.reader(csvfile, delimiter=',')
#     laptops_df = pd.DataFrame(csvreader)
    
# Raw data file
file_to_load = "Walmart_datasets/walmart_Laptop_data_file2.csv"
#file_to_load = "BestBuy_datasets/LaptopBestbuy.csv"


# Read purchasing file and store into pandas data frame
wal_laptop_df = pd.read_csv(file_to_load)
wal_laptop_df = wal_laptop_df.drop_duplicates()
wal_laptop_df = wal_laptop_df.drop(columns = ['categoryNode','categoryPath'])
wal_laptop_df = wal_laptop_df[['customerRating', 'name', 'numReviews', 'salePrice','upc']]


wal_laptop_df
# Out:
#      customerRating                                               name  \
# 0             4.667  HP Pavilion 15-cs0051wm 15.6 Touchscreen Lapto...
# 1             4.467  HP Pavilion 15-br082wm X360 15.6" Touchscreen ...
# 2             3.857  SAMSUNG Chromebook Plus 12.3"Chrome OS 32GB eM...
# 3             4.714  HP 15-da053wm 15.6" Touch Laptop, Windows 10 H...
# 4             4.348  Acer 15.6" Chromebook CB5-571-C4G4, Intel Cele...
# 5             3.551  Lenovo ideapad 320 15.6" Laptop, Windows 10, I...
# 6             1.667  Lenovo ideapad 330 15.6" Laptop, Windows 10, I...
# 7             4.182  HP Jaguar 15-bs060wm, 15.6" Touch Natural Silv...
# 8             0.000  HP 15-da0033wm 15.6" Touch Laptop, Windows 10 ...
# 9             4.061  Acer CB3-532-C47C 15.6" Chromebook, Chrome OS,...
# 10            3.793  HP Stream 14" Jet Black Laptop, Windows 10 Hom...
# 11            4.667  Lenovo ideapad 330 15.6" Laptop, Windows 10, I...
# 12            4.294  HP 15-da0032wm 15.6" Laptop, Windows 10 Home, ...
# 13            2.400  iView MAXIMUS III - 11.6" Convertible Touchscr...
# 14            4.051  HP 15-ay039wm 15.6" Silver Fusion Laptop, Wind...
# 15            4.071  HP 15-bs244wm 15.6" Touchscreen Laptop, Window...
# 16            3.000  iView MEGATRON II - 14.1" Convertible Touchscr...
# 17            3.000  HP 15-bw004wm 15.6" Pale Mint Laptop, Windows ...
# 18            5.000  HP 14-ak045wm 14” Chromebook, Chrome OS, Full ...
# 19            2.758  14" Ultra Slim Laptop, Windows 10 Home, Office...
# 20            3.667  Dell Inspiron 15.6" - Intel Core i5 - 8GB 2400...
# 21            3.000  HP 15-bs234wm 15.6" Laptop, Windows 10, Intel ...
# 22            2.971  HP Stream 14" Laptop, Windows 10 Home, Office ...
# 23            3.656  HP Stream 14-ax030wm 14” Smoke Gray, Windows 1...
# 24            4.500  HP Silver Iridium Ci5 15-cc050wm 15.6" Laptop,...
# 25            3.967  Acer A315-51-380T 15.6" Laptop, 7th Gen Intel ...
# 26            5.000  HP Chromebook 11 G5 - Education Edition - 11.6...
# 27            3.297  HP 15-bs020WM, 15.6" Touch Laptop, Windows 10,...
# 28            4.800  Acer Chromebook 14 CB3-431-C6ZB - 14" - Celero...
# 29            3.955  HP 15-ay041wm 15.6" Silver Fusion Laptop, Touc...
# ..              ...                                                ...
# 840           4.609                Targus Topload Case for 16" Laptops
# 841           0.000  Dell Latitude 3480, 14" HD Laptop Intel Core i...
# 842           0.000  Refurbished HP 810 G1 11.6" Laptop, Touchscree...
# 843           0.000  Dell Latitude 5480 - 14" - Core i7 7600U - 8 G...
# 844           0.000  HP Flagship High Performance 15.6" HD Touchscr...
# 845           0.000  HP Flagship High Performance 15.6" HD Touchscr...
# 846           5.000  Refurbished Lenovo Black 12.5" ThinkPad X230 W...
# 847           0.000  HP Premium High Perfomarce 17.3" Laptop, AMD Q...
# 848           0.000  Refurbished HP 840 G1 14" Laptop, Windows 10 P...
# 849           4.500  Refurbished HP Silver 14" EliteBook 8460P WA5-...
# 850           0.000  HP Stream Notebook 14-ax027cl 14" Screen, Cele...
# 851           0.000  HP Stream 14-ax010ca - 14" - Celeron N 1.6GHz ...
# 852           0.000  Lenovo Legion Y520 Gaming Laptop: Core i7-7700...
# 853           0.000  HP ENVY 13.3" 4K Touchscreen Laptop i7-8550U 1...
# 854           0.000  Lenovo ThinkPad P71 Mobile Workstation Laptop ...
# 855           0.000  Refurbished Dell Latitude E6430 Laptop Core i7...
# 856           0.000  Refurbished HP Folio 9470M 14" Laptop, Windows...
# 857           0.000  Refurbished HP Elitebook 8440p Laptop Notebook...
# 858           0.000  Refurbished Asus 15.6 Laptop i5 1.6GHz 8GB 750...
# 859           0.000  Refurbished Dell Silver 13.3" Latitude E6330 W...
# 860           3.167  Refurbished HP 14" EliteBook 8440P Laptop PC w...
# 861           3.722  Dell Silver 13.3" XPS 13 Laptop PC with Intel ...
# 862           2.000  Refurbished Lenovo 15.6" Thinkpad T520 Laptop ...
# 863           4.061  Dell XPS i7-8550U 16GB 1TB SSD Intel UHD Graph...
# 864           0.000  HP Envy 17t Premium 17.3 inch Touch Laptop (In...
# 865           0.000  Refurbished Apple MacBook Air 11.6" LED Laptop...
# 866           2.000  Refurbished HP Elitebook 8470p Laptop WEBCAM, ...
# 867           0.000  HP Premium 15.6 inch Touchscreen Laptop (Intel...
# 868           0.000  Lenovo Yoga 720-15IKB 80X7 - Flip design - Cor...
# 869           0.000  Refurbished Dell E7240 12.5" Laptop, Windows 1...
#
#      numReviews  salePrice           upc
# 0             3     639.00  192545383455
# 1            31     499.00  192018968349
# 2            56     429.95  887276183961
# 3            14     559.00  192545383752
# 4            21     179.00  888863275496
# 5           139     319.99  191545914829
# 6             3     349.00  192563997221
# 7            22     442.99  190781885658
# 8             0     469.00  192545382540
# 9           198     169.00  888863811427
# 10           29     212.98  191628693696
# 11            3     249.00  192651208383
# 12           17     429.00  192545382533
# 13            5     129.00  880010013548
# 14          294     446.00  889899806517
# 15           13     349.00  192545103411
# 16           12     129.00  880010013586
# 17           20     249.00  191628993017
# 18            1     169.00  192545800235
# 19           33     179.00  827396534212
# 20            9     429.00  884116277149
# 21            7     299.00  192545103459
# 22          139     199.00  190780429617
# 23           32     216.10  191628063758
# 24           32     517.00  190781891659
# 25           30     349.99  191114458686
# 26            1     159.00  190781580164
# 27           37     324.00  191628345618
# 28           15     219.00  888863814268
# 29          132     469.00  889899757697
# ..          ...        ...           ...
# 840          23      20.00   92636265052
# 841           0     625.19  884116258216
# 842           0     367.50  825633436121
# 843           0    1281.97  884116260516
# 844           0     383.00  615317531392
# 845           0     383.00  615317531392
# 846           1     286.92  825633354524
# 847           0     489.00  674023060565
# 848           0     341.00  825633402270
# 849           4     249.00  825633351493
# 850           0     180.00  705911318359
# 851           0     179.99  705911318748
# 852           0     949.00  191376651733
# 853           0     925.78  192018052086
# 854           0    3199.11  889800707490
# 855           0     394.95   40960490954
# 856           0     294.09  825633428706
# 857           0     205.97  680596411871
# 858           0     299.00  686727601371
# 859           0     368.00  825633354173
# 860          12     234.00  825633323247
# 861        2917     949.11  884116167495
# 862           4     467.54  825633345638
# 863        1916    1849.00  884116305040
# 864           0    1399.00  689353679974
# 865           0     399.95  600171630497
# 866           1     249.95  680596412038
# 867           0     786.45  689354176410
# 868           0    1298.99  191376215218
# 869           0     379.99  825633433502
#
# [870 rows x 5 columns]
