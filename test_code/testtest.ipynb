# %%
import pandas as pd
types_df = pd.read_csv("walmart_Laptop_data_file2.csv")
types_df.head()
# Out:
#    Unnamed: 0       categoryNode  \
# 0           0  3944_3951_1089430
# 1           1  3944_3951_1089430
# 2           2  3944_3951_1089430
# 3           3  3944_3951_1089430
# 4           4  3944_3951_1089430
#
#                                         categoryPath  customerRating  \
# 0  Electronics/Computers/Laptops/Shop Laptops by ...           4.667
# 1  Electronics/Computers/Laptops/Shop Laptops by ...           4.467
# 2  Electronics/Computers/Laptops/Shop Laptops by ...           3.857
# 3  Electronics/Computers/Laptops/Shop Laptops by ...           4.714
# 4  Electronics/Computers/Laptops/Shop Laptops by ...           4.348
#
#       itemId                                         largeImage  \
# 0  322570741  https://i5.walmartimages.com/asr/a5ec9c67-9a09...
# 1  822597407  https://i5.walmartimages.com/asr/c9095299-7506...
# 2   55499365  https://i5.walmartimages.com/asr/45426f9d-8ac4...
# 3  700792078  https://i5.walmartimages.com/asr/730c7807-89f9...
# ...
