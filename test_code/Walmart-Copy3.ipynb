# %% [markdown]
# # Walmart API overview
# ##### Search API used for look ups. We will use this first
# ##### Taxonomy API used for classifications.  We want to find a way to count classifications

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import urllib
import json
import sys
import pprint

# We are using 2 api Keys for redundancy and because
# there is a limit to the number of calls
api_key = "4tsbjxvbrwnpcjdsh277csqu"
api_alt = "anrtcd5dheh9758z5wgdy677"

# Base url for all API look ups
base_url = "http://api.walmartlabs.com/v1/" 

# Variables to specify the API
search = "search?"
paginated_products = "paginated/items?"

# Base url for search
search_url = base_url + search
paginated_url = base_url + paginated_products

# %% [markdown]
# # Search API

# %%
# Load search criteria for Walmart Search API.
# reference URL: https://developer.walmartlabs.com/docs/read/Search_API

format = "json"
categoryId = "3944"
query = "laptop"
numItems = 25 # max 25. 10 is default
start = 1
sort = "price"
order = "desc"
facet = "on" # boolean
min = str(0) # lower end of range for search within price range
max = str(200) # higher end of range price for search with price range
facet_range = (f"price:[{min}%20TO%20{max}]") # note the format [num1:num2] does not work. Use %20TO%20 for ":"



# NOTE: we are using 2 methods to create urls. Because the params argument does not format the output
# in the manner needed to get the API to work.  This is used only for price range lookups

# manual url. Used for price range lookup only
manual_url = (f"{search_url}apiKey={api_key}&format={format}&categoryId={categoryId}&query={query}&numItems={numItems}&facet={facet}&facet.range={facet_range}")

print(manual_url)

# API parameters for other lookups
params = {
    "apiKey": api_key,
    #"start": start, # note keep turned off.  We can't get this to work yet
    "format": "json", # json|xml
    "categoryId": categoryId,
    "query": query,
    "numItems": numItems,
    #"sort": sort, #allowed sort types are [relevance, price, title, bestseller, customerRating, new]
    #"order": order,  #allowed values are [asc, desc]
    #"facet":facet, # note keep turned off.  We can't get this to work yet
    #"facet.range":facet_range    # note keep turned off.  We can't get this to work yet
}
# Out:
# http://api.walmartlabs.com/v1/search?apiKey=4tsbjxvbrwnpcjdsh277csqu&format=json&categoryId=3944&query=laptop&numItems=25&facet=on&facet.range=price:[0%20TO%20200]

# %%
# Loop by pricing parameters to pull out entire data set for a product category
# to save time we are going to hard code some numbers then go back later if we have time

# Number of items found in our search
# there are 20,747 total results for laptop in electronics
# step 0 there are 3089 results in the price range $0-$200
# step 1 there are 3015 results in the price range $201-$400
# step 2 there are 2053 results in the price range $401-$600
# step 3 there are 2995 results in the price range $601-$1000
# step 4 there are 2021 results in the price range $1001-$1400
# step 5 there are 2726 results in the price range $1401-$1800
# step 6 there are 1873 results in the price range $1801-$2200
# step 7 there are 1011 results in the price range $2201-$2600
# step 8 there are 863 results in the price range $2601-3000
# step 9 there are 1096 results in the price range above $3000

category_total = 20747 #hard coded from broad search
step0 = 200*25//3089
step1 = 200*25//3015
step2 = 200*25//2053
step3 = 400*25//2995
step4 = 400*25//2021
step5 = 400*25//2726
step6 = 400*25//1873
step7 = 400*25//1011
step8 = 400*25//863

# create a function to perform the price search

def price_data(lowRange, highRange):
    facet_range = (f"price:[{lowRange}%20TO%20{highRange}]")
    price_url = (f"{search_url}apiKey={api_alt}&format={format}&categoryId={categoryId}&query={query}&numItems={numItems}&facet={facet}&facet.range={facet_range}")
    walmart_data2 = requests.get(price_url)
    walmart_data2 = walmart_data2.json()
    
    try:       
        a = []
        if not os.path.isfile('Walmart_datasets2/walmart_more.json'):
            a.append(walmart_data2)
            with open('Walmart_datasets2/walmart_more.json', mode='w') as f:
                f.write(json.dumps(walmart_data2, indent=4))
        else:
            with open('Walmart_datasets2/walmart_more.json') as feedsjson:
                feeds = json.load(feedsjson)

            feeds.append(walmart_data2)
            with open('Walmart_datasets/walmart_more.json', mode='w') as f:
                f.write(json.dumps(feeds, indent=4))

    except:
        print ("Skipped line")

# %%
# Use for loop to go through prices in the steps defined

searchCount = 0
itemCount = 0
low = 0
high = 0

for itemCount in range (0,21000):
    itemCount = (searchCount+1)*25
    if high < 200:
        high = low + step0
        price_data(low,high)
        low = high
        searchCount += 1
        print(f"search / item count = {searchCount} / {itemCount}")
    elif high < 400:
        high = low + step1
        price_data(low,high)
        low = high
        searchCount += 1
        print(f"search / item count = {searchCount} / {itemCount}")
    elif high < 600:
        high = low + step2
        price_data(low,high)
        low = high
        searchCount += 1
        print(f"search / item count = {searchCount} / {itemCount}")
    elif high < 1000:
        high = low + step3
        price_data(low,high)
        low = high
        searchCount += 1
        print(f"search / item count = {searchCount} / {itemCount}")            
    elif high < 1400:
        high = low + step4
        price_data(low,high)
        low = high
        searchCount += 1
        print(f"search / item count = {searchCount} / {itemCount}")    
    elif high < 1800:
        high = low + step5
        price_data(low,high)
        low = high
        searchCount += 1
        print(f"search / item count = {searchCount} / {itemCount}")
    elif high < 2200:
        high = low + step6
        price_data(low,high)
        low = high
        searchCount += 1
        print(f"search / item count = {searchCount} / {itemCount}")        
    elif high < 2600:
        high = low + step7
        price_data(low,high)
        low = high
        searchCount += 1
        print(f"search / item count = {searchCount} / {itemCount}")
    elif high < 3000:
        high = low + step8
        price_data(low,high)
        low = high
        searchCount += 1
        print(f"search / item count = {searchCount} / {itemCount}")
    elif high < 8000:
        high = low + step9
        price_data(low,high)
        low = high
        searchCount += 1
        print(f"search / item count = {searchCount} / {itemCount}")
    else:
        print ('finished')
        print (f'item count = {itemCount}')
        print (f'final search count = {searchCount}')
        print (f'final high price is ${high}')
        break
# Out:
# search / item count = 1 / 25
# Skipped line
# search / item count = 2 / 50
# Skipped line
# search / item count = 3 / 75
# Skipped line
# search / item count = 4 / 100
# Skipped line
# search / item count = 5 / 125
# Skipped line
# search / item count = 6 / 150
# Skipped line
# search / item count = 7 / 175
# Skipped line
# search / item count = 8 / 200
# Skipped line
# search / item count = 9 / 225
# Skipped line
# search / item count = 10 / 250
# Skipped line
# search / item count = 11 / 275
# Skipped line
# search / item count = 12 / 300
# Skipped line
# search / item count = 13 / 325
# Skipped line
# search / item count = 14 / 350
# Skipped line
# search / item count = 15 / 375
# Skipped line
# search / item count = 16 / 400
# Skipped line
# search / item count = 17 / 425
# Skipped line
# search / item count = 18 / 450
# Skipped line
# search / item count = 19 / 475
# Skipped line
# search / item count = 20 / 500
# Skipped line
# search / item count = 21 / 525
# Skipped line
# search / item count = 22 / 550
# Skipped line
# search / item count = 23 / 575
# Skipped line
# search / item count = 24 / 600
# Skipped line
# search / item count = 25 / 625
# Skipped line
# search / item count = 26 / 650
# Skipped line
# search / item count = 27 / 675
# Skipped line
# search / item count = 28 / 700
# Skipped line
# search / item count = 29 / 725
# Skipped line
# search / item count = 30 / 750
# Skipped line
# search / item count = 31 / 775
# Skipped line
# search / item count = 32 / 800
# Skipped line
# search / item count = 33 / 825
# Skipped line
# search / item count = 34 / 850
# Skipped line
# search / item count = 35 / 875
# Skipped line
# search / item count = 36 / 900
# Skipped line
# search / item count = 37 / 925
# Skipped line
# search / item count = 38 / 950
# Skipped line
# search / item count = 39 / 975
# Skipped line
# search / item count = 40 / 1000
# Skipped line
# search / item count = 41 / 1025
# Skipped line
# search / item count = 42 / 1050
# Skipped line
# search / item count = 43 / 1075
# Skipped line
# search / item count = 44 / 1100
# Skipped line
# search / item count = 45 / 1125
# Skipped line
# search / item count = 46 / 1150
# Skipped line
# search / item count = 47 / 1175
# Skipped line
# search / item count = 48 / 1200
# Skipped line
# search / item count = 49 / 1225
# Skipped line
# search / item count = 50 / 1250
# Skipped line
# search / item count = 51 / 1275
# Skipped line
# search / item count = 52 / 1300
# Skipped line
# search / item count = 53 / 1325
# Skipped line
# search / item count = 54 / 1350
# Skipped line
# search / item count = 55 / 1375
# Skipped line
# search / item count = 56 / 1400
# Skipped line
# search / item count = 57 / 1425
# Skipped line
# search / item count = 58 / 1450
# Skipped line
# search / item count = 59 / 1475
# Skipped line
# search / item count = 60 / 1500
# Skipped line
# search / item count = 61 / 1525
# Skipped line
# search / item count = 62 / 1550
# Skipped line
# search / item count = 63 / 1575
# Skipped line
# search / item count = 64 / 1600
# Skipped line
# search / item count = 65 / 1625
# Skipped line
# search / item count = 66 / 1650
# Skipped line
# search / item count = 67 / 1675
# Skipped line
# search / item count = 68 / 1700
# Skipped line
# search / item count = 69 / 1725
# Skipped line
# search / item count = 70 / 1750
# Skipped line
# search / item count = 71 / 1775
# Skipped line
# search / item count = 72 / 1800
# Skipped line
# search / item count = 73 / 1825
# Skipped line
# search / item count = 74 / 1850
# Skipped line
# search / item count = 75 / 1875
# Skipped line
# search / item count = 76 / 1900
# Skipped line
# search / item count = 77 / 1925
# Skipped line
# search / item count = 78 / 1950
# Skipped line
# search / item count = 79 / 1975
# Skipped line
# search / item count = 80 / 2000
# Skipped line
# search / item count = 81 / 2025
# Skipped line
# search / item count = 82 / 2050
# Skipped line
# search / item count = 83 / 2075
# Skipped line
# search / item count = 84 / 2100
# Skipped line
# search / item count = 85 / 2125
# Skipped line
# search / item count = 86 / 2150
# Skipped line
# search / item count = 87 / 2175
# Skipped line
# search / item count = 88 / 2200
# Skipped line
# search / item count = 89 / 2225
# Skipped line
# search / item count = 90 / 2250
# Skipped line
# search / item count = 91 / 2275
# Skipped line
# search / item count = 92 / 2300
# Skipped line
# search / item count = 93 / 2325
# Skipped line
# search / item count = 94 / 2350
# Skipped line
# search / item count = 95 / 2375
# Skipped line
# search / item count = 96 / 2400
# Skipped line
# search / item count = 97 / 2425
# Skipped line
# search / item count = 98 / 2450
# Skipped line
# search / item count = 99 / 2475
# Skipped line
# search / item count = 100 / 2500
# Skipped line
# search / item count = 101 / 2525
# Skipped line
# search / item count = 102 / 2550
# Skipped line
# search / item count = 103 / 2575
# Skipped line
# search / item count = 104 / 2600
# Skipped line
# search / item count = 105 / 2625
# Skipped line
# search / item count = 106 / 2650
# Skipped line
# search / item count = 107 / 2675
# Skipped line
# search / item count = 108 / 2700
# Skipped line
# search / item count = 109 / 2725
# Skipped line
# search / item count = 110 / 2750
# Skipped line
# search / item count = 111 / 2775
# Skipped line
# search / item count = 112 / 2800
# Skipped line
# search / item count = 113 / 2825
# Skipped line
# search / item count = 114 / 2850
# Skipped line
# search / item count = 115 / 2875
# Skipped line
# search / item count = 116 / 2900
# Skipped line
# search / item count = 117 / 2925
# Skipped line
# search / item count = 118 / 2950
# Skipped line
# search / item count = 119 / 2975
# Skipped line
# search / item count = 120 / 3000
# Skipped line
# search / item count = 121 / 3025
# Skipped line
# search / item count = 122 / 3050
# Skipped line
# search / item count = 123 / 3075
# Skipped line
# search / item count = 124 / 3100
# Skipped line
# search / item count = 125 / 3125
# Skipped line
# search / item count = 126 / 3150
# Skipped line
# search / item count = 127 / 3175
# Skipped line
# search / item count = 128 / 3200
# Skipped line
# search / item count = 129 / 3225
# Skipped line
# search / item count = 130 / 3250
# Skipped line
# search / item count = 131 / 3275
# Skipped line
# search / item count = 132 / 3300
# Skipped line
# search / item count = 133 / 3325
# Skipped line
# search / item count = 134 / 3350
# Skipped line
# search / item count = 135 / 3375
# Skipped line
# search / item count = 136 / 3400
# Skipped line
# search / item count = 137 / 3425
# Skipped line
# search / item count = 138 / 3450
# Skipped line
# search / item count = 139 / 3475
# Skipped line
# search / item count = 140 / 3500
# Skipped line
# search / item count = 141 / 3525
# Skipped line
# search / item count = 142 / 3550
# Skipped line
# search / item count = 143 / 3575
# Skipped line
# search / item count = 144 / 3600
# Skipped line
# search / item count = 145 / 3625
# Skipped line
# search / item count = 146 / 3650
# Skipped line
# search / item count = 147 / 3675
# Skipped line
# search / item count = 148 / 3700
# Skipped line
# search / item count = 149 / 3725
# Skipped line
# search / item count = 150 / 3750
# Skipped line
# search / item count = 151 / 3775
# Skipped line
# search / item count = 152 / 3800
# Skipped line
# search / item count = 153 / 3825
# Skipped line
# search / item count = 154 / 3850
# Skipped line
# search / item count = 155 / 3875
# Skipped line
# search / item count = 156 / 3900
# Skipped line
# search / item count = 157 / 3925
# Skipped line
# search / item count = 158 / 3950
# Skipped line
# search / item count = 159 / 3975
# Skipped line
# search / item count = 160 / 4000
# Skipped line
# search / item count = 161 / 4025
# Skipped line
# search / item count = 162 / 4050
# Skipped line
# search / item count = 163 / 4075
# Skipped line
# search / item count = 164 / 4100
# Skipped line
# search / item count = 165 / 4125
# Skipped line
# search / item count = 166 / 4150
# Skipped line
# search / item count = 167 / 4175
# Skipped line
# search / item count = 168 / 4200
# Skipped line
# search / item count = 169 / 4225
# Skipped line
# search / item count = 170 / 4250
# Skipped line
# search / item count = 171 / 4275
# Skipped line
# search / item count = 172 / 4300
# Skipped line
# search / item count = 173 / 4325
# Skipped line
# search / item count = 174 / 4350
# Skipped line
# search / item count = 175 / 4375
# Skipped line
# search / item count = 176 / 4400
# Skipped line
# search / item count = 177 / 4425
# Skipped line
# search / item count = 178 / 4450
# Skipped line
# search / item count = 179 / 4475
# Skipped line
# search / item count = 180 / 4500
# Skipped line
# search / item count = 181 / 4525
# Skipped line
# search / item count = 182 / 4550
# Skipped line
# search / item count = 183 / 4575
# Skipped line
# search / item count = 184 / 4600
# Skipped line
# search / item count = 185 / 4625
# Skipped line
# search / item count = 186 / 4650
# Skipped line
# search / item count = 187 / 4675
# Skipped line
# search / item count = 188 / 4700
# Skipped line
# search / item count = 189 / 4725
# Skipped line
# search / item count = 190 / 4750
# Skipped line
# search / item count = 191 / 4775
# Skipped line
# search / item count = 192 / 4800
# Skipped line
# search / item count = 193 / 4825
# Skipped line
# search / item count = 194 / 4850
# Skipped line
# search / item count = 195 / 4875
# Skipped line
# search / item count = 196 / 4900
# Skipped line
# search / item count = 197 / 4925
# Skipped line
# search / item count = 198 / 4950
# Skipped line
# search / item count = 199 / 4975
# Skipped line
# search / item count = 200 / 5000
# Skipped line
# search / item count = 201 / 5025
# Skipped line
# search / item count = 202 / 5050
# Skipped line
# search / item count = 203 / 5075
# Skipped line
# search / item count = 204 / 5100
# Skipped line
# search / item count = 205 / 5125
# Skipped line
# search / item count = 206 / 5150
# Skipped line
# search / item count = 207 / 5175
# Skipped line
# search / item count = 208 / 5200
# Skipped line
# search / item count = 209 / 5225
# Skipped line
# search / item count = 210 / 5250
# Skipped line
# search / item count = 211 / 5275
# Skipped line
# search / item count = 212 / 5300
# Skipped line
# search / item count = 213 / 5325
# Skipped line
# search / item count = 214 / 5350
# Skipped line
# search / item count = 215 / 5375
# Skipped line
# search / item count = 216 / 5400
# Skipped line
# search / item count = 217 / 5425
# Skipped line
# search / item count = 218 / 5450
# Skipped line
# search / item count = 219 / 5475
# Skipped line
# search / item count = 220 / 5500
# Skipped line
# search / item count = 221 / 5525
# Skipped line
# search / item count = 222 / 5550
# Skipped line
# search / item count = 223 / 5575
# Skipped line
# search / item count = 224 / 5600
# Skipped line
# search / item count = 225 / 5625
# Skipped line
# search / item count = 226 / 5650
# Skipped line
# search / item count = 227 / 5675
# Skipped line
# search / item count = 228 / 5700
# Skipped line
# search / item count = 229 / 5725
# Skipped line
# search / item count = 230 / 5750
# Skipped line
# search / item count = 231 / 5775
# Skipped line
# search / item count = 232 / 5800
# Skipped line
# search / item count = 233 / 5825
# Skipped line
# search / item count = 234 / 5850
# Skipped line
# search / item count = 235 / 5875
# Skipped line
# search / item count = 236 / 5900
# Skipped line
# search / item count = 237 / 5925
# Skipped line
# search / item count = 238 / 5950
# Skipped line
# search / item count = 239 / 5975
# Skipped line
# search / item count = 240 / 6000
# Skipped line
# search / item count = 241 / 6025
# Skipped line
# search / item count = 242 / 6050
# Skipped line
# search / item count = 243 / 6075
# Skipped line
# search / item count = 244 / 6100
# Skipped line
# search / item count = 245 / 6125
# Skipped line
# search / item count = 246 / 6150
# Skipped line
# search / item count = 247 / 6175
# Skipped line
# search / item count = 248 / 6200
# Skipped line
# search / item count = 249 / 6225
# Skipped line
# search / item count = 250 / 6250
# Skipped line
# search / item count = 251 / 6275
# Skipped line
# search / item count = 252 / 6300
# Skipped line
# search / item count = 253 / 6325
# Skipped line
# search / item count = 254 / 6350
# Skipped line
# search / item count = 255 / 6375
# Skipped line
# search / item count = 256 / 6400
# Skipped line
# search / item count = 257 / 6425
# Skipped line
# search / item count = 258 / 6450
# Skipped line
# search / item count = 259 / 6475
# Skipped line
# search / item count = 260 / 6500
# Skipped line
# search / item count = 261 / 6525
# Skipped line
# search / item count = 262 / 6550
# Skipped line
# search / item count = 263 / 6575
# Skipped line
# search / item count = 264 / 6600
# Skipped line
# search / item count = 265 / 6625
# Skipped line
# search / item count = 266 / 6650
# Skipped line
# search / item count = 267 / 6675
# Skipped line
# search / item count = 268 / 6700
# Skipped line
# search / item count = 269 / 6725
# Skipped line
# search / item count = 270 / 6750
# Skipped line
# search / item count = 271 / 6775
# Skipped line
# search / item count = 272 / 6800
# Skipped line
# search / item count = 273 / 6825
# Skipped line
# search / item count = 274 / 6850
# Skipped line
# search / item count = 275 / 6875
# Skipped line
# search / item count = 276 / 6900
# Skipped line
# search / item count = 277 / 6925
# Skipped line
# search / item count = 278 / 6950
# Skipped line
# search / item count = 279 / 6975
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-13-2c9dedeadbec> in <module>()
#      16     elif high < 400:
#      17         high = low + step1
# ---> 18         price_data(low,high)
#      19         low = high
#      20         searchCount += 1
#
# <ipython-input-12-a1f26daaf4b3> in price_data(lowRange, highRange)
#      32     price_url = (f"{search_url}apiKey={api_alt}&format={format}&categoryId={categoryId}&query={query}&numItems={numItems}&facet={facet}&facet.range={facet_range}")
#      33     walmart_data2 = requests.get(price_url)
# ---> 34     walmart_data2 = walmart_data2.json()
#      35
#      36     try:
#
# ~\Anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     890                     # used.
#     891                     pass
# --> 892         return complexjson.loads(self.text, **kwargs)
#     893
#     894     @property
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 3 column 1 (char 2)

# %%
from pprint import pprint
import os
filepath = os.path.join('Walmart_datasets2/walmart_more.json')
with open(filepath) as jsonfile:
    json_data = json.load(jsonfile)
    print (len(json_data))
    for i in range(len(json_data)):
        try:
            print (json_data['itemId'])
        except:
            print(f"skipped entry {i}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-7442d7fe2532> in <module>()
#       2 import os
#       3 filepath = os.path.join('Walmart_datasets/walmart_more.json')
# ----> 4 with open(filepath) as jsonfile:
#       5     json_data = json.load(jsonfile)
#       6     print (len(json_data))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Walmart_datasets/walmart_more.json'
