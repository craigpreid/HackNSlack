# %%
# Dependencies
import requests
import json

# %%
# URL for GET requests to retrieve vehicle data
url = "https://api.bestbuy.com/v1/products(search=macbook)?format=json&show=sku,department,name,onSale,priceUpdateDate,regularPrice,salesRankLongTerm,salesRankMediumTerm,salesRankShortTerm,lowPriceGuarantee,salePrice&apiKey=Jz4AJitfYbGIGGaOuTR09Lpl"

# %%
# Print the response object to the console
print(requests.get(url))
# Out:
# <Response [200]>

# %%
#res=requests.get(url).json()

# %%
# Pretty Print the output of the JSON
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "canonicalUrl": "/v1/products(search=\"macbook\")?show=sku,department,name,onSale,priceUpdateDate,regularPrice,salesRankLongTerm,salesRankMediumTerm,salesRankShortTerm,lowPriceGuarantee,salePrice&format=json&apiKey=Jz4AJitfYbGIGGaOuTR09Lpl",
#     "currentPage": 1,
#     "from": 1,
#     "partial": false,
#     "products": [
#         {
#             "department": "COMPUTER SOFTWARE",
#             "lowPriceGuarantee": false,
#             "name": "AppleCare+ for MacBook- 3 Year Plan",
#             "onSale": false,
#             "priceUpdateDate": "2017-09-01T08:21:31",
#             "regularPrice": 249.0,
#             "salePrice": 249.0,
#             "salesRankLongTerm": 276,
#             "salesRankMediumTerm": 197,
#             "salesRankShortTerm": 208,
#             "sku": 5886510
#         },
#         {
#             "department": "COMPUTER SOFTWARE",
#             "lowPriceGuarantee": false,
#             "name": "AppleCare+ for MacBook- 3 Year Plan",
# ...
