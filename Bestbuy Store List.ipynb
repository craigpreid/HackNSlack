# %%
# Dependencies
import requests
import json
import csv
import pandas as pd

# %%
url="https://api.bestbuy.com/v1/stores?apiKey=Jz4AJitfYbGIGGaOuTR09Lpl&show=address,address2,city,country,hours,hoursAmPm,lat,location,lng,name,longName,phone,fullPostalCode,services,region,storeId,storeType,tradeIn&pageSize=100&format=json"

# %%
print(requests.get(url))
# Out:
# <Response [200]>

# %%
# Pretty Print the output of the JSON
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "canonicalUrl": "/v1/stores?show=address,address2,city,country,hours,hoursAmPm,lat,location,lng,name,longName,phone,fullPostalCode,services,region,storeId,storeType,tradeIn&pageSize=100&format=json&apiKey=Jz4AJitfYbGIGGaOuTR09Lpl",
#     "currentPage": 1,
#     "from": 1,
#     "partial": false,
#     "queryTime": "0.017",
#     "stores": [
#         {
#             "address": "50 Holyoke St",
#             "address2": "",
#             "city": "Holyoke",
#             "country": "US",
#             "fullPostalCode": "01040-2709",
#             "hours": "Sun: 10-8; Mon: 10-9; Tue: 10-9; Wed: 10-9; Thurs: 10-9; Fri: 10-9; Sat: 10-9; Sun: 10-8; Mon: 10-9; Tue: 10-9; Wed: 10-9; Thurs: 10-9; Fri: 10-9; Sat: 10-9",
#             "hoursAmPm": "Sun: 10am-8pm; Mon: 10am-9pm; Tue: 10am-9pm; Wed: 10am-9pm; Thurs: 10am-9pm; Fri: 10am-9pm; Sat: 10am-9pm; Sun: 10am-8pm; Mon: 10am-9pm; Tue: 10am-9pm; Wed: 10am-9pm; Thurs: 10am-9pm; Fri: 10am-9pm; Sat: 10am-9pm",
# ...

# %%
store_list=response['stores']

# %%
storebestbuy_df = pd.DataFrame(store_list)
storebestbuy_df.head()
# Out:
#                         address address2        city country fullPostalCode  \
# 0                 50 Holyoke St              Holyoke      US     01040-2709
# 1       33 Orchard Hill Park Dr           Leominster      US     01453-7019
# 2  70 Worcester Providence Tpke  Ste 140    Millbury      US     01527-2652
# 3                 7 Neponset St            Worcester      US     01606-2794
# 4                1 Worcester Rd           Framingham      US     01701-5359
#
#                                                hours  \
# 0  Sun: 10-8; Mon: 10-9; Tue: 10-9; Wed: 10-9; Th...
# 1  Sun: 11-8; Mon: 10-9; Tue: 10-9; Wed: 10-9; Th...
# 2  Sun: 11-8; Mon: 10-9; Tue: 10-9; Wed: 10-9; Th...
# 3  Sun: 11-8; Mon: 10-9; Tue: 10-9; Wed: 10-9; Th...
# 4  Sun: 11-8; Mon: 10-9; Tue: 10-9; Wed: 10-9; Th...
#
#                                            hoursAmPm       lat       lng  \
# 0  Sun: 10am-8pm; Mon: 10am-9pm; Tue: 10am-9pm; W...  42.16931 -72.64198
# ...
